# %% [markdown]
# ## Решение домашнего задания к уроку 3. TensorFlow

# %% [markdown]
# ### Задание:
# #### Используя файл Web3.ipynb (он в полезных ссылках):
#
# Постройте нейронную сеть (берем несложную полносвязную сеть, меняем число слоев, число нейронов, типы активации, тип оптимизатора) на датасете from sklearn.datasets import load_boston.
#
# Постройте 10-15 вариантов разных нейронных сетей и сведите результаты их работы в таблицу. Опишите, какого результата вы добились от нейросети? Что помогло вам улучшить ее точность?

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.models import Sequential, Model

# %matplotlib inline

# %%
tf.random.set_seed(1)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
boston_dataset = load_boston()
print(boston_dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston['target'] = boston_dataset.target
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  target
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98    24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14    21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03    34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94    33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33    36.2
#
# [5 rows x 14 columns]

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT      target
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677083   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
X = boston.drop(['target'], axis=1)
y = boston['target']

# %%
corr_with_target = boston.corr().iloc[:-1, -1].sort_values(ascending=False)

plt.figure(figsize=(10, 8))

sns.barplot(x=corr_with_target.values, y=corr_with_target.index)

plt.title('Correlation with target variable')
plt.show()

# %%
# Масштабирование
X_sc = StandardScaler().fit(X).transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sc, y, test_size = 0.3, random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (354, 13)
# (152, 13)
# (354,)
# (152,)

# %%
results = pd.DataFrame() # сводная таблица результатов
n_layers = [] # число слоев
n_nums = [] # число нейронов
act_func = [] # функция активации
opt = [] # оптимизатор
train_mse = [] # ошибка на тренировочной выборке
test_mse = [] # ошибка на тестовой выборке

# %% [markdown]
# Будем проверять следующие значения:<br>
# n_layers: 3, 5 и 10 <br>
# n_nums: 8, 32 и 128 <br>
# act_func: ReLU, sigmoid и tanh <br>
# opt: RMSProp и Adam<br>

# %%
# Рассмотрим 3-слойную сеть
fig = plt.figure(figsize=(30,20))
plt.subplots_adjust(wspace=0.1, hspace=0.5)
k = 0
for n in [8, 32, 128]:
  for f in ['relu', 'sigmoid', 'tanh']:
    k += 1
    for o in ['RMSprop', 'Adam']:
      n_layers.append(3)
      n_nums.append(n)
      act_func.append(f)
      opt.append(o)
      
      print(f'\nПараметры текущей нейронной сети: 3 слоя, {n} нейронов, функция активации {f}, оптимизатор {o}...')

      inputs = Input(shape=(13,))
      x_1 = Flatten()(inputs)
      x_2 = Dense(n, activation=f)(x_1)
      outputs = Dense(1)(x_2)

      model = Model(inputs, outputs)

      model.compile(optimizer=o,
                    loss='mse',
                    metrics=['mse'])

      #model.summary()

      history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=5,
                    validation_data=(X_test, y_test), 
                    verbose=0)

      train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
      test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
      train_mse.append(train_m)
      test_mse.append(test_m)
      
      ax = fig.add_subplot(6, 2, k)
      ax.plot(history.history['val_mse'], label=f'val {o} {round(test_m,2)}')
      ax.plot(history.history['mse'], label=f'train {o} {round(train_m,2)}')
      ax.legend()
      ax.set_xlabel('epoch')
      ax.set_ylabel('mse')
      ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
plt.show()
# Out:
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 240.7857 - mse: 240.7857 - 64ms/epoch - 5ms/step
# 5/5 - 0s - loss: 246.4820 - mse: 246.4820 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 325.4369 - mse: 325.4369 - 42ms/epoch - 3ms/step
# 5/5 - 0s - loss: 302.0543 - mse: 302.0543 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 12/12 - 0s - loss: 405.0438 - mse: 405.0438 - 51ms/epoch - 4ms/step
# 5/5 - 0s - loss: 384.4337 - mse: 384.4337 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 420.8575 - mse: 420.8575 - 43ms/epoch - 4ms/step
# 5/5 - 0s - loss: 399.2807 - mse: 399.2807 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 422.8160 - mse: 422.8160 - 39ms/epoch - 3ms/step
# 5/5 - 0s - loss: 408.5339 - mse: 408.5339 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 389.0745 - mse: 389.0745 - 39ms/epoch - 3ms/step
# 5/5 - 0s - loss: 382.2343 - mse: 382.2343 - 32ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 32.9649 - mse: 32.9649 - 41ms/epoch - 3ms/step
# 5/5 - 0s - loss: 45.0849 - mse: 45.0849 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 40.5945 - mse: 40.5945 - 39ms/epoch - 3ms/step
# 5/5 - 0s - loss: 55.1182 - mse: 55.1182 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 127.9779 - mse: 127.9779 - 55ms/epoch - 5ms/step
# 5/5 - 0s - loss: 129.7080 - mse: 129.7080 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 134.3645 - mse: 134.3645 - 41ms/epoch - 3ms/step
# 5/5 - 0s - loss: 134.0177 - mse: 134.0177 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 133.7848 - mse: 133.7848 - 39ms/epoch - 3ms/step
# 5/5 - 0s - loss: 148.1151 - mse: 148.1151 - 26ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 124.0414 - mse: 124.0414 - 40ms/epoch - 3ms/step
# 5/5 - 0s - loss: 138.1192 - mse: 138.1192 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 16.3955 - mse: 16.3955 - 42ms/epoch - 4ms/step
# 5/5 - 0s - loss: 28.4058 - mse: 28.4058 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 19.4441 - mse: 19.4441 - 44ms/epoch - 4ms/step
# 5/5 - 0s - loss: 32.0605 - mse: 32.0605 - 27ms/epoch - 5ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 24.4299 - mse: 24.4299 - 43ms/epoch - 4ms/step
# 5/5 - 0s - loss: 33.1892 - mse: 33.1892 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 26.5485 - mse: 26.5485 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 35.3146 - mse: 35.3146 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 23.8244 - mse: 23.8244 - 43ms/epoch - 4ms/step
# 5/5 - 0s - loss: 30.1088 - mse: 30.1088 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 22.9670 - mse: 22.9670 - 43ms/epoch - 4ms/step
# 5/5 - 0s - loss: 31.3401 - mse: 31.3401 - 29ms/epoch - 6ms/step

# %%
# Рассмотрим 5-слойную сеть
fig = plt.figure(figsize=(30,20))
plt.subplots_adjust(wspace=0.1, hspace=0.5)
k = 0
for n in [8, 32, 128]:
  for f in ['relu', 'sigmoid', 'tanh']:
    k += 1
    for o in ['RMSprop', 'Adam']:
      n_layers.append(5)
      n_nums.append(n)
      act_func.append(f)
      opt.append(o)
      
      print(f'\nПараметры текущей нейронной сети: 5 слоёв, {n} нейронов, функция активации {f}, оптимизатор {o}...')

      inputs = Input(shape=(13,))
      x_1 = Flatten()(inputs)
      x_2 = Dense(n, activation=f)(x_1)
      x_3 = Dense(n, activation=f)(x_2)
      x_4 = Dense(n, activation=f)(x_3)
      outputs = Dense(1)(x_4)

      model = Model(inputs, outputs)

      model.compile(optimizer=o,
                    loss='mse',
                    metrics=['mse'])

      #model.summary()

      history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=5,
                    validation_data=(X_test, y_test), 
                    verbose=0)

      train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
      test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
      train_mse.append(train_m)
      test_mse.append(test_m)
      
      ax = fig.add_subplot(6, 2, k)
      ax.plot(history.history['val_mse'], label=f'val {o} {round(test_m,2)}')
      ax.plot(history.history['mse'], label=f'train {o} {round(train_m,2)}')
      ax.legend()
      ax.set_xlabel('epoch')
      ax.set_ylabel('mse')
      ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
plt.show()
# Out:
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 39.7534 - mse: 39.7534 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 58.0080 - mse: 58.0080 - 32ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 21.3374 - mse: 21.3374 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 34.4205 - mse: 34.4205 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 12/12 - 0s - loss: 307.0653 - mse: 307.0653 - 46ms/epoch - 4ms/step
# 5/5 - 0s - loss: 284.9846 - mse: 284.9846 - 34ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 296.8604 - mse: 296.8604 - 43ms/epoch - 4ms/step
# 5/5 - 0s - loss: 275.3015 - mse: 275.3015 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 277.8910 - mse: 277.8910 - 49ms/epoch - 4ms/step
# 5/5 - 0s - loss: 257.2967 - mse: 257.2967 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 221.0708 - mse: 221.0708 - 42ms/epoch - 3ms/step
# 5/5 - 0s - loss: 208.4846 - mse: 208.4846 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 12.5604 - mse: 12.5604 - 75ms/epoch - 6ms/step
# 5/5 - 0s - loss: 22.8320 - mse: 22.8320 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 9.7680 - mse: 9.7680 - 90ms/epoch - 8ms/step
# 5/5 - 0s - loss: 21.0657 - mse: 21.0657 - 53ms/epoch - 11ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 93.8772 - mse: 93.8772 - 43ms/epoch - 4ms/step
# 5/5 - 0s - loss: 88.5249 - mse: 88.5249 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 112.0729 - mse: 112.0729 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 103.6459 - mse: 103.6459 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 57.0906 - mse: 57.0906 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 57.0506 - mse: 57.0506 - 39ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 64.3487 - mse: 64.3487 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 61.3611 - mse: 61.3611 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 13.6905 - mse: 13.6905 - 44ms/epoch - 4ms/step
# 5/5 - 0s - loss: 20.0331 - mse: 20.0331 - 33ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 7.5889 - mse: 7.5889 - 48ms/epoch - 4ms/step
# 5/5 - 0s - loss: 17.5304 - mse: 17.5304 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 35.3412 - mse: 35.3412 - 44ms/epoch - 4ms/step
# 5/5 - 0s - loss: 42.5161 - mse: 42.5161 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 59.0384 - mse: 59.0384 - 43ms/epoch - 4ms/step
# 5/5 - 0s - loss: 61.5732 - mse: 61.5732 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 11.3324 - mse: 11.3324 - 46ms/epoch - 4ms/step
# 5/5 - 0s - loss: 19.0435 - mse: 19.0435 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 14.2820 - mse: 14.2820 - 41ms/epoch - 3ms/step
# 5/5 - 0s - loss: 18.8798 - mse: 18.8798 - 27ms/epoch - 5ms/step

# %%
# Рассмотрим 10-слойную сеть
fig = plt.figure(figsize=(30,20))
plt.subplots_adjust(wspace=0.1, hspace=0.5)
k = 0
for n in [8, 32, 128]:
  for f in ['relu', 'sigmoid', 'tanh']:
    k += 1
    for o in ['RMSprop', 'Adam']:
      n_layers.append(10)
      n_nums.append(n)
      act_func.append(f)
      opt.append(o)
      
      print(f'\nПараметры текущей нейронной сети: 10 слоёв, {n} нейронов, функция активации {f}, оптимизатор {o}...')

      inputs = Input(shape=(13,))
      x_1 = Flatten()(inputs)
      x_2 = Dense(n, activation=f)(x_1)
      x_3 = Dense(n, activation=f)(x_2)
      x_4 = Dense(n, activation=f)(x_3)
      x_5 = Dense(n, activation=f)(x_4)
      x_6 = Dense(n, activation=f)(x_5)
      x_7 = Dense(n, activation=f)(x_6)
      x_8 = Dense(n, activation=f)(x_7)
      x_9 = Dense(n, activation=f)(x_8)
      outputs = Dense(1)(x_9)

      model = Model(inputs, outputs)

      model.compile(optimizer=o,
                    loss='mse',
                    metrics=['mse'])

      #model.summary()

      history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=5,
                    validation_data=(X_test, y_test), 
                    verbose=0)

      train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
      test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
      train_mse.append(train_m)
      test_mse.append(test_m)
      
      ax = fig.add_subplot(6, 2, k)
      ax.plot(history.history['val_mse'], label=f'val {o} {round(test_m,2)}')
      ax.plot(history.history['mse'], label=f'train {o} {round(train_m,2)}')
      ax.legend()
      ax.set_xlabel('epoch')
      ax.set_ylabel('mse')
      ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
plt.show()
# Out:
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 17.0995 - mse: 17.0995 - 48ms/epoch - 4ms/step
# 5/5 - 0s - loss: 27.5599 - mse: 27.5599 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 21.1367 - mse: 21.1367 - 44ms/epoch - 4ms/step
# 5/5 - 0s - loss: 34.4910 - mse: 34.4910 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:47: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 12/12 - 0s - loss: 404.0328 - mse: 404.0328 - 44ms/epoch - 4ms/step
# 5/5 - 0s - loss: 377.7345 - mse: 377.7345 - 28ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 352.5201 - mse: 352.5201 - 47ms/epoch - 4ms/step
# 5/5 - 0s - loss: 328.3526 - mse: 328.3526 - 40ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 266.8665 - mse: 266.8665 - 48ms/epoch - 4ms/step
# 5/5 - 0s - loss: 246.7611 - mse: 246.7611 - 33ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 237.3122 - mse: 237.3122 - 43ms/epoch - 4ms/step
# 5/5 - 0s - loss: 218.8559 - mse: 218.8559 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 26.2714 - mse: 26.2714 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 31.8798 - mse: 31.8798 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 9.3763 - mse: 9.3763 - 46ms/epoch - 4ms/step
# 5/5 - 0s - loss: 18.3567 - mse: 18.3567 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 89.2990 - mse: 89.2990 - 47ms/epoch - 4ms/step
# 5/5 - 0s - loss: 85.2860 - mse: 85.2860 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 119.8582 - mse: 119.8582 - 59ms/epoch - 5ms/step
# 5/5 - 0s - loss: 110.4723 - mse: 110.4723 - 31ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 84.9520 - mse: 84.9520 - 50ms/epoch - 4ms/step
# 5/5 - 0s - loss: 83.3373 - mse: 83.3373 - 30ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 86.8889 - mse: 86.8889 - 49ms/epoch - 4ms/step
# 5/5 - 0s - loss: 83.8207 - mse: 83.8207 - 34ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 71.4739 - mse: 71.4739 - 69ms/epoch - 6ms/step
# 5/5 - 0s - loss: 63.7912 - mse: 63.7912 - 34ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 5.4715 - mse: 5.4715 - 50ms/epoch - 4ms/step
# 5/5 - 0s - loss: 13.8689 - mse: 13.8689 - 35ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 77.4184 - mse: 77.4184 - 48ms/epoch - 4ms/step
# 5/5 - 0s - loss: 77.9787 - mse: 77.9787 - 33ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 84.7653 - mse: 84.7653 - 47ms/epoch - 4ms/step
# 5/5 - 0s - loss: 83.8072 - mse: 83.8072 - 33ms/epoch - 7ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 29.6837 - mse: 29.6837 - 47ms/epoch - 4ms/step
# 5/5 - 0s - loss: 34.8058 - mse: 34.8058 - 29ms/epoch - 6ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 79.0350 - mse: 79.0350 - 45ms/epoch - 4ms/step
# 5/5 - 0s - loss: 83.5976 - mse: 83.5976 - 29ms/epoch - 6ms/step

# %%
results['n_layers'] = n_layers
results['n_nums'] = n_nums
results['act_func'] = act_func
results['opt'] = opt
results['train_mse'] = train_mse
results['test_mse'] = test_mse
results['overtr_diff'] = results['test_mse'] - results['train_mse']

# %%
results.sort_values(by=['test_mse','overtr_diff'], ascending=[True, True])
# Out:
#     n_layers  n_nums act_func      opt   train_mse    test_mse  overtr_diff
# 49        10     128     relu     Adam    5.471531   13.868859     8.397328
# 31         5     128     relu     Adam    7.588863   17.530399     9.941536
# 43        10      32     relu     Adam    9.376311   18.356693     8.980382
# 35         5     128     tanh     Adam   14.282034   18.879822     4.597788
# 34         5     128     tanh  RMSprop   11.332442   19.043503     7.711061
# 30         5     128     relu  RMSprop   13.690454   20.033102     6.342649
# 25         5      32     relu     Adam    9.767986   21.065746    11.297760
# 24         5      32     relu  RMSprop   12.560369   22.832024    10.271655
# 36        10       8     relu  RMSprop   17.099506   27.559917    10.460411
# 12         3     128     relu  RMSprop   16.395510   28.405771    12.010262
# 16         3     128     tanh  RMSprop   23.824404   30.108761     6.284357
# 17         3     128     tanh     Adam   22.966988   31.340120     8.373133
# 42        10      32     relu  RMSprop   26.271423   31.879822     5.608398
# 13         3     128     relu     Adam   19.444088   32.060493    12.616405
# 14         3     128  sigmoid  RMSprop   24.429945   33.189171     8.759226
# 19         5       8     relu     Adam   21.337425   34.420464    13.083038
# 37        10       8     relu     Adam   21.136744   34.490978    13.354235
# 52        10     128     tanh  RMSprop   29.683651   34.805775     5.122124
# 15         3     128  sigmoid     Adam   26.548519   35.314568     8.766048
# 32         5     128  sigmoid  RMSprop   35.341213   42.516125     7.174911
# 6          3      32     relu  RMSprop   32.964912   45.084881    12.119968
# 7          3      32     relu     Adam   40.594528   55.118183    14.523655
# 28         5      32     tanh  RMSprop   57.090588   57.050556    -0.040031
# 18         5       8     relu  RMSprop   39.753384   58.008007    18.254623
# 29         5      32     tanh     Adam   64.348686   61.361115    -2.987572
# 33         5     128  sigmoid     Adam   59.038380   61.573193     2.534813
# 48        10     128     relu  RMSprop   71.473938   63.791210    -7.682728
# 50        10     128  sigmoid  RMSprop   77.418449   77.978699     0.560249
# 46        10      32     tanh  RMSprop   84.951981   83.337341    -1.614639
# 53        10     128     tanh     Adam   79.035034   83.597618     4.562584
# 51        10     128  sigmoid     Adam   84.765297   83.807205    -0.958092
# 47        10      32     tanh     Adam   86.888939   83.820656    -3.068283
# 44        10      32  sigmoid  RMSprop   89.298958   85.285988    -4.012970
# 26         5      32  sigmoid  RMSprop   93.877159   88.524879    -5.352280
# 27         5      32  sigmoid     Adam  112.072914  103.645897    -8.427017
# 45        10      32  sigmoid     Adam  119.858185  110.472267    -9.385918
# 8          3      32  sigmoid  RMSprop  127.977875  129.708008     1.730133
# 9          3      32  sigmoid     Adam  134.364517  134.017715    -0.346802
# 11         3      32     tanh     Adam  124.041443  138.119156    14.077713
# 10         3      32     tanh  RMSprop  133.784775  148.115112    14.330338
# 23         5       8     tanh     Adam  221.070770  208.484573   -12.586197
# 41        10       8     tanh     Adam  237.312210  218.855911   -18.456299
# 0          3       8     relu  RMSprop  240.785736  246.481964     5.696228
# 40        10       8     tanh  RMSprop  266.866547  246.761078   -20.105469
# 22         5       8     tanh  RMSprop  277.891022  257.296661   -20.594360
# 21         5       8  sigmoid     Adam  296.860443  275.301514   -21.558929
# 20         5       8  sigmoid  RMSprop  307.065338  284.984619   -22.080719
# 1          3       8     relu     Adam  325.436890  302.054291   -23.382599
# 39        10       8  sigmoid     Adam  352.520081  328.352600   -24.167480
# 38        10       8  sigmoid  RMSprop  404.032837  377.734528   -26.298309
# 5          3       8     tanh     Adam  389.074463  382.234344    -6.840118
# 2          3       8  sigmoid  RMSprop  405.043823  384.433685   -20.610138
# 3          3       8  sigmoid     Adam  420.857513  399.280670   -21.576843
# 4          3       8     tanh  RMSprop  422.815979  408.533936   -14.282043

# %% [markdown]
# ### Выводы
# 1. Лучшее качество получилось на максимальном количестве слоев (10) и максимальном количестве нейронов (128). Обратное также прослеживается на графиках: чем меньше слоев и нейронов - тем больше ошибка.
# 2. Наименьшая ошибка получилась с оптимизатором Adam. Но в целом, RMSprop не сильно ему уступает.

# %% [markdown]
# Лушее качество получилось при [10,	128, relu,	Adam]: <br>
# То есть получили сравнительно небольшую ошибку, но довольно большое переобучение.<br>
# Получим предсказания модели для обех выборок:

# %%
inputs = Input(shape=(13,))
x_1 = Flatten()(inputs)
x_2 = Dense(128, activation='relu')(x_1)
x_3 = Dense(128, activation='relu')(x_2)
x_4 = Dense(128, activation='relu')(x_3)
x_5 = Dense(128, activation='relu')(x_4)
x_6 = Dense(128, activation='relu')(x_5)
x_7 = Dense(128, activation='relu')(x_6)
x_8 = Dense(128, activation='relu')(x_7)
x_9 = Dense(128, activation='relu')(x_8)
outputs = Dense(1)(x_9)

model = Model(inputs, outputs)

model.compile(optimizer='Adam',
                    loss='mse',
                    metrics=['mse'])

model.summary()

history = model.fit(X_train, y_train, 
                    epochs=10, 
                    batch_size=5, 
                    validation_data=(X_test, y_test), 
                    verbose=1)

train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
# Out:
# Model: "model_116"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_117 (InputLayer)      [(None, 13)]              0
#
#  flatten_116 (Flatten)       (None, 13)                0
#
#  dense_556 (Dense)           (None, 128)               1792
#
#  dense_557 (Dense)           (None, 128)               16512
#
#  dense_558 (Dense)           (None, 128)               16512
#
#  dense_559 (Dense)           (None, 128)               16512
#
#  dense_560 (Dense)           (None, 128)               16512
#
#  dense_561 (Dense)           (None, 128)               16512
#
#  dense_562 (Dense)           (None, 128)               16512
#
#  dense_563 (Dense)           (None, 128)               16512
#
#  dense_564 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 117,505
# Trainable params: 117,505
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 71/71 [==============================] - 4s 24ms/step - loss: 139.6400 - mse: 139.6400 - val_loss: 35.0371 - val_mse: 35.0371
# Epoch 2/10
# 71/71 [==============================] - 1s 20ms/step - loss: 28.0578 - mse: 28.0578 - val_loss: 39.7984 - val_mse: 39.7984
# Epoch 3/10
# 71/71 [==============================] - 1s 15ms/step - loss: 17.6795 - mse: 17.6795 - val_loss: 29.9044 - val_mse: 29.9044
# Epoch 4/10
# 71/71 [==============================] - 1s 12ms/step - loss: 14.6964 - mse: 14.6964 - val_loss: 22.8281 - val_mse: 22.8281
# Epoch 5/10
# 71/71 [==============================] - 1s 12ms/step - loss: 18.1388 - mse: 18.1388 - val_loss: 21.1847 - val_mse: 21.1847
# Epoch 6/10
# 71/71 [==============================] - 1s 15ms/step - loss: 10.4203 - mse: 10.4203 - val_loss: 19.1910 - val_mse: 19.1910
# Epoch 7/10
# 71/71 [==============================] - 1s 13ms/step - loss: 15.8802 - mse: 15.8802 - val_loss: 24.5836 - val_mse: 24.5836
# Epoch 8/10
# 71/71 [==============================] - 1s 16ms/step - loss: 12.3593 - mse: 12.3593 - val_loss: 18.3444 - val_mse: 18.3444
# Epoch 9/10
# 71/71 [==============================] - 1s 15ms/step - loss: 7.6225 - mse: 7.6225 - val_loss: 18.5628 - val_mse: 18.5628
# Epoch 10/10
# 71/71 [==============================] - 1s 13ms/step - loss: 8.2391 - mse: 8.2391 - val_loss: 16.1849 - val_mse: 16.1849
# 12/12 - 0s - loss: 8.5579 - mse: 8.5579 - 49ms/epoch - 4ms/step
# 5/5 - 0s - loss: 16.1849 - mse: 16.1849 - 32ms/epoch - 6ms/step

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f'Коэффициент детерминации на тренировочной выборке: {round(r2_train,2)}')
print(f'Коэффициент детерминации на тестовой выборке: {round(r2_test,2)}')
# Out:
# Коэффициент детерминации на тренировочной выборке: 0.9
# Коэффициент детерминации на тестовой выборке: 0.81

# %% [markdown]
# У нас получилось переобучение в 9%, что в целом, хорошо.

# %% [markdown]
# ### Общий вывод
# **Опишите, какого результата вы добились от нейросети? Что помогло вам улучшить ее точность?**<br>
# В итоге добились сравнительно неплохого качества модели. <br>
# Точность увеличивается с ростом числа слоев и числа нейронов. Но надо не забывать про переобучение.<br>
# Оптимизаторы и функции активации надо подбирать исходя из количества слоев и нейронов, так как разные значения показывают разное качество и нет ярко-выраженной зависимости. <br>
# Для задач регрессии больше подходят функции активации relu.<br>
