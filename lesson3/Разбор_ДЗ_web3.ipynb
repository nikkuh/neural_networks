# %% [markdown]
# ## Решение домашнего задания к уроку 3. TensorFlow

# %% [markdown]
# ### Задание:
# #### Используя файл Web3.ipynb (он в полезных ссылках):
#
# Постройте нейронную сеть (берем несложную полносвязную сеть, меняем число слоев, число нейронов, типы активации, тип оптимизатора) на датасете from sklearn.datasets import load_boston.
#
# Постройте 10-15 вариантов разных нейронных сетей и сведите результаты их работы в таблицу. Опишите, какого результата вы добились от нейросети? Что помогло вам улучшить ее точность?

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.models import Sequential, Model

# %matplotlib inline

# %%
tf.random.set_seed(1)

# %%
tf.config.list_physical_devices('CPU')
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
boston_dataset = load_boston()
print(boston_dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston['target'] = boston_dataset.target
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT      target
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
X = boston.drop(['target'], axis=1)
y = boston['target']

# %%
corr_with_target = boston.corr().iloc[:-1, -1].sort_values(ascending=False)

plt.figure(figsize=(10, 8))

sns.barplot(x=corr_with_target.values, y=corr_with_target.index)

plt.title('Correlation with target variable')
plt.show()

# %%
# Масштабирование
X_sc = StandardScaler().fit(X).transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sc, y, test_size = 0.3, random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (354, 13)
# (152, 13)
# (354,)
# (152,)

# %%
results = pd.DataFrame() # сводная таблица результатов
n_layers = [] # число слоев
n_nums = [] # число нейронов
act_func = [] # функция активации
opt = [] # оптимизатор
train_mse = [] # ошибка на тренировочной выборке
test_mse = [] # ошибка на тестовой выборке

# %% [markdown]
# Будем проверять следующие значения:<br>
# n_layers: 3, 5 и 10 <br>
# n_nums: 8, 32 и 128 <br>
# act_func: ReLU, sigmoid и tanh <br>
# opt: RMSProp и Adam<br>

# %%
# Рассмотрим 3-слойную сеть
fig = plt.figure(figsize=(30,20))
plt.subplots_adjust(wspace=0.1, hspace=0.5)
k = 0
for n in [8, 32, 128]:
    for f in ['relu', 'sigmoid', 'tanh']:
        k += 1
        for o in ['RMSprop', 'Adam']:
            n_layers.append(3)
            n_nums.append(n)
            act_func.append(f)
            opt.append(o)
      
            print(f'\nПараметры текущей нейронной сети: 3 слоя, {n} нейронов, функция активации {f}, оптимизатор {o}...')

            inputs = Input(shape=(13,))
            x_1 = Flatten()(inputs)
            x_2 = Dense(n, activation=f)(x_1)
            outputs = Dense(1)(x_2)

            model = Model(inputs, outputs)

            model.compile(optimizer=o,
                        loss='mse',
                        metrics=['mse'])

            #model.summary()

            history = model.fit(X_train, y_train,
                        epochs=10,
                        batch_size=5,
                        validation_data=(X_test, y_test), 
                        verbose=0)

            train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
            test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
            train_mse.append(train_m)
            test_mse.append(test_m)

            ax = fig.add_subplot(6, 2, k)
            ax.plot(history.history['val_mse'], label=f'val {o} {round(test_m,2)}')
            ax.plot(history.history['mse'], label=f'train {o} {round(train_m,2)}')
            ax.legend()
            ax.set_xlabel('epoch')
            ax.set_ylabel('mse')
            ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
plt.show()
# Out:
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 273.1398 - mse: 273.1398 - 55ms/epoch - 5ms/step
# 5/5 - 0s - loss: 257.8633 - mse: 257.8633 - 59ms/epoch - 12ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 119.1402 - mse: 119.1402 - 54ms/epoch - 4ms/step
# 5/5 - 0s - loss: 136.1827 - mse: 136.1827 - 52ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 399.7454 - mse: 399.7454 - 56ms/epoch - 5ms/step
# 5/5 - 0s - loss: 380.6629 - mse: 380.6629 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 409.7921 - mse: 409.7921 - 47ms/epoch - 4ms/step
# 5/5 - 0s - loss: 388.8920 - mse: 388.8920 - 41ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 393.5731 - mse: 393.5731 - 54ms/epoch - 5ms/step
# 5/5 - 0s - loss: 387.9418 - mse: 387.9418 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 8 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 389.2747 - mse: 389.2747 - 53ms/epoch - 4ms/step
# 5/5 - 0s - loss: 383.1866 - mse: 383.1866 - 39ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 39.3353 - mse: 39.3353 - 48ms/epoch - 4ms/step
# 5/5 - 0s - loss: 51.5805 - mse: 51.5805 - 40ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 38.3136 - mse: 38.3136 - 49ms/epoch - 4ms/step
# 5/5 - 0s - loss: 54.6595 - mse: 54.6595 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 126.9181 - mse: 126.9181 - 55ms/epoch - 5ms/step
# 5/5 - 0s - loss: 127.9386 - mse: 127.9386 - 41ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 144.3631 - mse: 144.3631 - 70ms/epoch - 6ms/step
# 5/5 - 0s - loss: 143.9337 - mse: 143.9337 - 45ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 149.9835 - mse: 149.9835 - 48ms/epoch - 4ms/step
# 5/5 - 0s - loss: 164.8826 - mse: 164.8826 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 32 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 126.5070 - mse: 126.5070 - 54ms/epoch - 4ms/step
# 5/5 - 0s - loss: 139.7022 - mse: 139.7022 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 19.1354 - mse: 19.1354 - 52ms/epoch - 4ms/step
# 5/5 - 0s - loss: 31.4271 - mse: 31.4271 - 45ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 18.3595 - mse: 18.3595 - 58ms/epoch - 5ms/step
# 5/5 - 0s - loss: 30.8498 - mse: 30.8498 - 59ms/epoch - 12ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 24.0307 - mse: 24.0307 - 49ms/epoch - 4ms/step
# 5/5 - 0s - loss: 32.7976 - mse: 32.7976 - 42ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 27.2012 - mse: 27.2012 - 56ms/epoch - 5ms/step
# 5/5 - 0s - loss: 36.0833 - mse: 36.0833 - 42ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 23.6126 - mse: 23.6126 - 54ms/epoch - 4ms/step
# 5/5 - 0s - loss: 30.5621 - mse: 30.5621 - 40ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 3 слоя, 128 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 22.8921 - mse: 22.8921 - 49ms/epoch - 4ms/step
# 5/5 - 0s - loss: 31.1834 - mse: 31.1834 - 43ms/epoch - 9ms/step

# %%
# Рассмотрим 5-слойную сеть
fig = plt.figure(figsize=(30,20))
plt.subplots_adjust(wspace=0.1, hspace=0.5)
k = 0
for n in [8, 32, 128]:
    for f in ['relu', 'sigmoid', 'tanh']:
        k += 1
        for o in ['RMSprop', 'Adam']:
            n_layers.append(5)
            n_nums.append(n)
            act_func.append(f)
            opt.append(o)

            print(f'\nПараметры текущей нейронной сети: 5 слоёв, {n} нейронов, функция активации {f}, оптимизатор {o}...')

            inputs = Input(shape=(13,))
            x_1 = Flatten()(inputs)
            x_2 = Dense(n, activation=f)(x_1)
            x_3 = Dense(n, activation=f)(x_2)
            x_4 = Dense(n, activation=f)(x_3)
            outputs = Dense(1)(x_4)

            model = Model(inputs, outputs)

            model.compile(optimizer=o,
                        loss='mse',
                        metrics=['mse'])

            #model.summary()

            history = model.fit(X_train, y_train,
                        epochs=10,
                        batch_size=5,
                        validation_data=(X_test, y_test), 
                        verbose=0)

            train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
            test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
            train_mse.append(train_m)
            test_mse.append(test_m)

            ax = fig.add_subplot(6, 2, k)
            ax.plot(history.history['val_mse'], label=f'val {o} {round(test_m,2)}')
            ax.plot(history.history['mse'], label=f'train {o} {round(train_m,2)}')
            ax.legend()
            ax.set_xlabel('epoch')
            ax.set_ylabel('mse')
            ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
plt.show()
# Out:
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 27.1617 - mse: 27.1617 - 57ms/epoch - 5ms/step
# 5/5 - 0s - loss: 38.2439 - mse: 38.2439 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 27.7420 - mse: 27.7420 - 54ms/epoch - 5ms/step
# 5/5 - 0s - loss: 41.7667 - mse: 41.7667 - 42ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 393.1701 - mse: 393.1701 - 57ms/epoch - 5ms/step
# 5/5 - 0s - loss: 367.3058 - mse: 367.3058 - 48ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 382.3015 - mse: 382.3015 - 49ms/epoch - 4ms/step
# 5/5 - 0s - loss: 356.9336 - mse: 356.9336 - 50ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 255.5015 - mse: 255.5015 - 59ms/epoch - 5ms/step
# 5/5 - 0s - loss: 236.2294 - mse: 236.2294 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 8 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 246.4081 - mse: 246.4081 - 49ms/epoch - 4ms/step
# 5/5 - 0s - loss: 227.8586 - mse: 227.8586 - 44ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 11.8079 - mse: 11.8079 - 56ms/epoch - 5ms/step
# 5/5 - 0s - loss: 22.7125 - mse: 22.7125 - 42ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 10.2431 - mse: 10.2431 - 50ms/epoch - 4ms/step
# 5/5 - 0s - loss: 21.9120 - mse: 21.9120 - 40ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 95.7865 - mse: 95.7865 - 54ms/epoch - 5ms/step
# 5/5 - 0s - loss: 90.0787 - mse: 90.0787 - 48ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 141.8911 - mse: 141.8911 - 51ms/epoch - 4ms/step
# 5/5 - 0s - loss: 130.1906 - mse: 130.1906 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 55.4348 - mse: 55.4348 - 60ms/epoch - 5ms/step
# 5/5 - 0s - loss: 56.4691 - mse: 56.4691 - 60ms/epoch - 12ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 32 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 57.3923 - mse: 57.3923 - 70ms/epoch - 6ms/step
# 5/5 - 0s - loss: 57.0961 - mse: 57.0961 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 14.3584 - mse: 14.3584 - 60ms/epoch - 5ms/step
# 5/5 - 0s - loss: 20.2374 - mse: 20.2374 - 65ms/epoch - 13ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 7.2591 - mse: 7.2591 - 58ms/epoch - 5ms/step
# 5/5 - 0s - loss: 16.6933 - mse: 16.6933 - 66ms/epoch - 13ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 32.1726 - mse: 32.1726 - 55ms/epoch - 5ms/step
# 5/5 - 0s - loss: 39.7721 - mse: 39.7721 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 53.2016 - mse: 53.2016 - 84ms/epoch - 7ms/step
# 5/5 - 0s - loss: 58.1934 - mse: 58.1934 - 41ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 11.1880 - mse: 11.1880 - 51ms/epoch - 4ms/step
# 5/5 - 0s - loss: 18.5326 - mse: 18.5326 - 52ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 5 слоёв, 128 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 14.7483 - mse: 14.7483 - 60ms/epoch - 5ms/step
# 5/5 - 0s - loss: 21.6388 - mse: 21.6388 - 45ms/epoch - 9ms/step

# %%
# Рассмотрим 10-слойную сеть
fig = plt.figure(figsize=(30,20))
plt.subplots_adjust(wspace=0.1, hspace=0.5)
k = 0
for n in [8, 32, 128]:
    for f in ['relu', 'sigmoid', 'tanh']:
        k += 1
        for o in ['RMSprop', 'Adam']:
            n_layers.append(10)
            n_nums.append(n)
            act_func.append(f)
            opt.append(o)

            print(f'\nПараметры текущей нейронной сети: 10 слоёв, {n} нейронов, функция активации {f}, оптимизатор {o}...')

            inputs = Input(shape=(13,))
            x_1 = Flatten()(inputs)
            x_2 = Dense(n, activation=f)(x_1)
            x_3 = Dense(n, activation=f)(x_2)
            x_4 = Dense(n, activation=f)(x_3)
            x_5 = Dense(n, activation=f)(x_4)
            x_6 = Dense(n, activation=f)(x_5)
            x_7 = Dense(n, activation=f)(x_6)
            x_8 = Dense(n, activation=f)(x_7)
            x_9 = Dense(n, activation=f)(x_8)
            outputs = Dense(1)(x_9)

            model = Model(inputs, outputs)

            model.compile(optimizer=o,
                        loss='mse',
                        metrics=['mse'])

            #model.summary()

            history = model.fit(X_train, y_train,
                        epochs=10,
                        batch_size=5,
                        validation_data=(X_test, y_test), 
                        verbose=0)

            train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
            test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
            train_mse.append(train_m)
            test_mse.append(test_m)

            ax = fig.add_subplot(6, 2, k)
            ax.plot(history.history['val_mse'], label=f'val {o} {round(test_m,2)}')
            ax.plot(history.history['mse'], label=f'train {o} {round(train_m,2)}')
            ax.legend()
            ax.set_xlabel('epoch')
            ax.set_ylabel('mse')
            ax.set(title = f'Ошибка сети от эпох при {n} нейронах и функции активации {f}')
plt.show()
# Out:
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 22.2989 - mse: 22.2989 - 58ms/epoch - 5ms/step
# 5/5 - 0s - loss: 35.4645 - mse: 35.4645 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 20.3055 - mse: 20.3055 - 52ms/epoch - 4ms/step
# 5/5 - 0s - loss: 33.7223 - mse: 33.7223 - 45ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 338.7186 - mse: 338.7186 - 58ms/epoch - 5ms/step
# 5/5 - 0s - loss: 315.1562 - mse: 315.1562 - 44ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 302.5973 - mse: 302.5973 - 57ms/epoch - 5ms/step
# 5/5 - 0s - loss: 280.7012 - mse: 280.7012 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 273.4622 - mse: 273.4622 - 55ms/epoch - 5ms/step
# 5/5 - 0s - loss: 253.0138 - mse: 253.0138 - 41ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 8 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 243.1791 - mse: 243.1791 - 55ms/epoch - 5ms/step
# 5/5 - 0s - loss: 224.3623 - mse: 224.3623 - 40ms/epoch - 8ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 18.1867 - mse: 18.1867 - 50ms/epoch - 4ms/step
# 5/5 - 0s - loss: 22.4792 - mse: 22.4792 - 44ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 9.6879 - mse: 9.6879 - 73ms/epoch - 6ms/step
# 5/5 - 0s - loss: 21.8888 - mse: 21.8888 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 92.2517 - mse: 92.2517 - 52ms/epoch - 4ms/step
# 5/5 - 0s - loss: 87.3795 - mse: 87.3795 - 44ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 131.6169 - mse: 131.6169 - 54ms/epoch - 5ms/step
# 5/5 - 0s - loss: 120.9271 - mse: 120.9271 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 89.0821 - mse: 89.0821 - 59ms/epoch - 5ms/step
# 5/5 - 0s - loss: 81.1741 - mse: 81.1741 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 32 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 87.7733 - mse: 87.7733 - 57ms/epoch - 5ms/step
# 5/5 - 0s - loss: 84.3202 - mse: 84.3202 - 48ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации relu, оптимизатор RMSprop...
# 12/12 - 0s - loss: 82.8456 - mse: 82.8456 - 63ms/epoch - 5ms/step
# 5/5 - 0s - loss: 73.7226 - mse: 73.7226 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации relu, оптимизатор Adam...
# 12/12 - 0s - loss: 7.4174 - mse: 7.4174 - 71ms/epoch - 6ms/step
# 5/5 - 0s - loss: 15.8154 - mse: 15.8154 - 47ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор RMSprop...
# 12/12 - 0s - loss: 51.8540 - mse: 51.8540 - 62ms/epoch - 5ms/step
# 5/5 - 0s - loss: 58.2632 - mse: 58.2632 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации sigmoid, оптимизатор Adam...
# 12/12 - 0s - loss: 84.7665 - mse: 84.7665 - 70ms/epoch - 6ms/step
# 5/5 - 0s - loss: 83.8323 - mse: 83.8323 - 48ms/epoch - 10ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации tanh, оптимизатор RMSprop...
# 12/12 - 0s - loss: 25.0814 - mse: 25.0814 - 54ms/epoch - 5ms/step
# 5/5 - 0s - loss: 30.1266 - mse: 30.1266 - 43ms/epoch - 9ms/step
#
# Параметры текущей нейронной сети: 10 слоёв, 128 нейронов, функция активации tanh, оптимизатор Adam...
# 12/12 - 0s - loss: 79.5600 - mse: 79.5600 - 55ms/epoch - 5ms/step
# 5/5 - 0s - loss: 121.9272 - mse: 121.9272 - 46ms/epoch - 9ms/step

# %%
results['n_layers'] = n_layers
results['n_nums'] = n_nums
results['act_func'] = act_func
results['opt'] = opt
results['train_mse'] = train_mse
results['test_mse'] = test_mse
results['overtr_diff'] = results['test_mse'] - results['train_mse']

# %%
results.sort_values(by=['test_mse','overtr_diff'], ascending=[True, True])
# Out:
#     n_layers  n_nums act_func      opt   train_mse    test_mse  overtr_diff
# 67        10     128     relu     Adam    7.417383   15.815392     8.398009
# 49         5     128     relu     Adam    7.259066   16.693289     9.434223
# 52         5     128     tanh  RMSprop   11.188027   18.532625     7.344598
# 48         5     128     relu  RMSprop   14.358442   20.237429     5.878986
# 53         5     128     tanh     Adam   14.748292   21.638838     6.890546
# ..       ...     ...      ...      ...         ...         ...          ...
# 22         3       8     tanh  RMSprop  393.573059  387.941772    -5.631287
# 21         3       8  sigmoid     Adam  409.792114  388.891968   -20.900146
# 5          3       8     tanh     Adam  399.855988  389.303467   -10.552521
# 2          3       8  sigmoid  RMSprop  470.701050  444.434174   -26.266876
# 3          3       8  sigmoid     Adam  477.744232  451.274414   -26.469818
#
# [72 rows x 7 columns]

# %% [markdown]
# ### Выводы
# 1. Лучшее качество получилось на максимальном количестве слоев (10) и максимальном количестве нейронов (128). Обратное также прослеживается на графиках: чем меньше слоев и нейронов - тем больше ошибка.
# 2. Наименьшая ошибка получилась с оптимизатором Adam. Но в целом, RMSprop не сильно ему уступает.

# %% [markdown]
# Лушее качество получилось при [10,	128, relu,	Adam]: <br>
# То есть получили сравнительно небольшую ошибку, но довольно большое переобучение.<br>
# Получим предсказания модели для обех выборок:

# %%
inputs = Input(shape=(13,))
x_1 = Flatten()(inputs)
x_2 = Dense(128, activation='relu')(x_1)
x_3 = Dense(128, activation='relu')(x_2)
x_4 = Dense(128, activation='relu')(x_3)
x_5 = Dense(128, activation='relu')(x_4)
x_6 = Dense(128, activation='relu')(x_5)
x_7 = Dense(128, activation='relu')(x_6)
x_8 = Dense(128, activation='relu')(x_7)
x_9 = Dense(128, activation='relu')(x_8)
outputs = Dense(1)(x_9)

model = Model(inputs, outputs)

model.compile(optimizer='Adam',
                    loss='mse',
                    metrics=['mse'])

model.summary()

history = model.fit(X_train, y_train, 
                    epochs=10, 
                    batch_size=5, 
                    validation_data=(X_test, y_test), 
                    verbose=1)

train_loss, train_m = model.evaluate(X_train, y_train, verbose=2)
test_loss, test_m = model.evaluate(X_test, y_test, verbose=2)
# Out:
# Model: "model_116"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_117 (InputLayer)      [(None, 13)]              0
#
#  flatten_116 (Flatten)       (None, 13)                0
#
#  dense_556 (Dense)           (None, 128)               1792
#
#  dense_557 (Dense)           (None, 128)               16512
#
#  dense_558 (Dense)           (None, 128)               16512
#
#  dense_559 (Dense)           (None, 128)               16512
#
#  dense_560 (Dense)           (None, 128)               16512
#
#  dense_561 (Dense)           (None, 128)               16512
#
#  dense_562 (Dense)           (None, 128)               16512
#
#  dense_563 (Dense)           (None, 128)               16512
#
#  dense_564 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 117,505
# Trainable params: 117,505
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 71/71 [==============================] - 4s 24ms/step - loss: 139.6400 - mse: 139.6400 - val_loss: 35.0371 - val_mse: 35.0371
# Epoch 2/10
# 71/71 [==============================] - 1s 20ms/step - loss: 28.0578 - mse: 28.0578 - val_loss: 39.7984 - val_mse: 39.7984
# Epoch 3/10
# 71/71 [==============================] - 1s 15ms/step - loss: 17.6795 - mse: 17.6795 - val_loss: 29.9044 - val_mse: 29.9044
# Epoch 4/10
# 71/71 [==============================] - 1s 12ms/step - loss: 14.6964 - mse: 14.6964 - val_loss: 22.8281 - val_mse: 22.8281
# Epoch 5/10
# 71/71 [==============================] - 1s 12ms/step - loss: 18.1388 - mse: 18.1388 - val_loss: 21.1847 - val_mse: 21.1847
# Epoch 6/10
# 71/71 [==============================] - 1s 15ms/step - loss: 10.4203 - mse: 10.4203 - val_loss: 19.1910 - val_mse: 19.1910
# Epoch 7/10
# 71/71 [==============================] - 1s 13ms/step - loss: 15.8802 - mse: 15.8802 - val_loss: 24.5836 - val_mse: 24.5836
# Epoch 8/10
# 71/71 [==============================] - 1s 16ms/step - loss: 12.3593 - mse: 12.3593 - val_loss: 18.3444 - val_mse: 18.3444
# Epoch 9/10
# 71/71 [==============================] - 1s 15ms/step - loss: 7.6225 - mse: 7.6225 - val_loss: 18.5628 - val_mse: 18.5628
# Epoch 10/10
# 71/71 [==============================] - 1s 13ms/step - loss: 8.2391 - mse: 8.2391 - val_loss: 16.1849 - val_mse: 16.1849
# 12/12 - 0s - loss: 8.5579 - mse: 8.5579 - 49ms/epoch - 4ms/step
# 5/5 - 0s - loss: 16.1849 - mse: 16.1849 - 32ms/epoch - 6ms/step

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f'Коэффициент детерминации на тренировочной выборке: {round(r2_train,2)}')
print(f'Коэффициент детерминации на тестовой выборке: {round(r2_test,2)}')
# Out:
# Коэффициент детерминации на тренировочной выборке: 0.9
# Коэффициент детерминации на тестовой выборке: 0.81

# %% [markdown]
# У нас получилось переобучение в 9%, что в целом, хорошо.

# %% [markdown]
# ### Общий вывод
# **Опишите, какого результата вы добились от нейросети? Что помогло вам улучшить ее точность?**<br>
# В итоге добились сравнительно неплохого качества модели. <br>
# Точность увеличивается с ростом числа слоев и числа нейронов. Но надо не забывать про переобучение.<br>
# Оптимизаторы и функции активации надо подбирать исходя из количества слоев и нейронов, так как разные значения показывают разное качество и нет ярко-выраженной зависимости. <br>
# Для задач регрессии больше подходят функции активации relu.<br>
